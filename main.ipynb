# %% [markdown]
# # Berlin LOR Housing Stock (source-aligned) - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/berlin-lor-housing-stock-2023-00-csv/berlin-lor-housing-stock-2023-00-9-planning-areas.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#         id  ... residential_buildings_with_3_apartments_apartments
# 0  3100102  ...                                            3100102
# 1  3100103  ...                                            3100103
# 2  3200204  ...                                            3200204
# 3  3200205  ...                                            3200205
# 4  3200206  ...                                            3200206
#
# [5 rows x 24 columns]

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   id                                                   40 non-null     int64
#  1   inhabitants                                          40 non-null     object
#  2   apartments                                           40 non-null     object
#  3   apartments_with_1_room                               40 non-null     object
#  4   apartments_with_2_rooms                              40 non-null     object
#  5   apartments_with_3_rooms                              40 non-null     object
#  6   apartments_with_4_rooms                              40 non-null     object
#  7   apartments_with_5_rooms                              40 non-null     object
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                  id  residential_buildings_with_3_apartments_apartments
# count  4.000000e+01                                       4.000000e+01
# mean   3.365646e+06                                       3.365646e+06
# std    1.314660e+05                                       1.314660e+05
# min    3.100102e+06                                       3.100102e+06
# 25%    3.300412e+06                                       3.300412e+06
# 50%    3.400722e+06                                       3.400722e+06
# 75%    3.425856e+06                                       3.425856e+06
# max    3.601141e+06                                       3.601141e+06
